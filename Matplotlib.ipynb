# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav3829/python_libraries/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
